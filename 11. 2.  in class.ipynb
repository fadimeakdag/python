# %%
my_age = 33
your_age = 30
my_age = your_age
print(my_age)
# Out:
# 30

# %%
VAR_ONE = "Something but nothing" #pep 8 e göre büyük harfle değişken oluşturma
VAR_ONE
# Out:
# 'Something but nothing'

# %%
x = y = z = "same"
print(x)
print(y)
print(z)
# Out:
# same
# same
# same

# %%
january = march = may = july = august = october = dcember = 31
february = 28
april = june = september = novamber = 30
print("january, february, march, april, may, june, july, august, october, dcember, september, novamber ")
# Out:
# january, february, march, april, may, june, july, august, october, dcember, september, novamber

# %%
thomas = 33
marry = 28
walter = None ? # None değişkene bir şey atamayacksak sonradan kullanacaksak none atarız 
isabella = 46

# %%
website = "apple.com"
website = "clarusway.com"
website
# Out:
# 'clarusway.com'

# %%
first_number = 100
second_number = first_number
print(second_number)
# Out:
# 100

# %%
x = 15
y = 33
z = x
x = y
print(x)
print(y)
print(z)
# Out:
# 33
# 33
# 15

# %%
a, b, c = 5, 3.2, "Hello"
print(a)
print(b)
print(c)
# Out:
# 5
# 3.2
# Hello

# %%
man = "andrew"
color = "green"
age = 32
pi = 3.14
color = "yellow"
age = 34
man = "josep"
print(age)
print(color)
print(man)
# Out:
# 34
# yellow
# josep

# %%
my_text = "being a good person"
print(my_text)
print(type(my_text))
type(my_text)
# Out:
# being a good person
# <class 'str'>
# str

# %%
type("ali, veli, deli") # tipini veriyor
# Out:
# str

# %%
str_number = "1923"
str_sign = 97
print(str_number)
print(str_sign)
print(type(str_number))
type(str_number)
# Out:
# 1923
# 97
# <class 'str'>
# str

# %%
my_data = 'I am string'
print(type(my_data))
# Out:
# <class 'str'>

# %%
str(3.14) # str her veri tipini str ye çevirebilir
# Out:
# '3.14'

# %%
str(False)
# Out:
# 'False'

# %%
pi = 3.14
int(3.14) # int de tam sayıyı çevirri . virgülü atar
# Out:
# 3

# %%
float(11)
# Out:
# 11.0

# %%
float("11")
# Out:
# 11.0

# %%
11/5
# Out:
# 2.2

# %%
11//5
# Out:
# 2

# %%
11%5
# Out:
# 1

# %%
11*5
# Out:
# 55

# %%
11**5
# Out:
# 161051

# %%
11-5
# Out:
# 6

# %%
11+5
# Out:
# 16

# %%
r = 5    # dairenin alanı hesaplaması (pi = 3.14  r = 5  area = pi *r**2 kural)
area = 3.14 *r**2
print(area)
# Out:
# 78.5

# %%
print(11%2)
print((4*5) / 2) # parantezden başlar ve / bu işaret float verir
# Out:
# 1
# 10.0

# %%
16**0.5
# Out:
# 4.0
