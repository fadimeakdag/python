# %%
değişken = 10
değişken
# Out:
# 10

# %%
değişken = değişken + 1
değişken
# Out:
# 11

# %%
değişken = değişken + 1
değişken
# Out:
# 16

# %%
değişken2 = 10
değişken2 = değişken2 * 2
değişken2
# Out:
# 20

# %%
değişken
# Out:
# 16

# %%
değişken += 1
değişken
# Out:
# 17

# %%
a = (1 + 3) ** (2 **(1 * 2 / 2) / 2)
print(a)
# Out:
# 4.0

# %%
değişken = değişken * 2  #ile değişken *= 2 aynı şeyler çarpıyor
değişken *= 2
değişken
# Out:
# 272

# %%
a = 8
b = 2
a += b
a
# Out:
# 10

# %%
a *= b
a
# Out:
# 20

# %%
a = 3 
b = 4
c = (a ** 2 + b ** 2) ** 0.5
c
# Out:
# 5.0

# %%
a = 3  # üçgenin hipotenüsü hesaplaması 
b = 4
c = (a **2 + b **2)**0.5
c
# Out:
# 5.0

# %%
print("ali")
print("veli", "veli")
print("selvi", "baharat" "44")
print(c, False, "ahmet", 3.14)
# Out:
# ali
# veli veli
# selvi baharat44
# 5.0 False ahmet 3.14

# %%
print(c, False, "ahmet ", 3.14,  sep = "-")
# Out:
# 5.0-False-ahmet -3.14

# %%
print("selvi", "baharat", 44, sep ="**")
# Out:
# selvi**baharat**44

# %%
print("ali", end = " ")
print("veli", "ayşe")
# Out:
# ali veli ayşe

# %%
text1 = "I bought"
text2 = "kg. of apple this morning"
amount = 6
text3 = text1  " "  + str(amount) " " + text2
print(text1, amount, text2)
print("I bought", 6, "kg. of apple this morning")
print("I bought " + "6 " + "kg. of apple this morning")
print(text3)
# Out:
#   File "<ipython-input-32-e5f9a3614800>", line 4
#     text3 = text1  " "  + str(amount) " " + text2
#                      ^
# SyntaxError: invalid syntax

# %%
print('ahmet'in ceketi') # hata verir
# Out:
#   File "<ipython-input-34-060b5e99909d>", line 1
#     print('ahmet'in ceketi')
#                             ^
# SyntaxError: EOL while scanning string literal

# %%
print('ahmet\'in ceketi') # ters slaş tırnak ı normal tırnaka çevrir
# Out:
# ahmet'in ceketi

# %%
True and True and True # en son True çıktı verdi
# Out:
# True

# %%
1 and 2 and 3 # truty
# Out:
# 3

# %%
bool(None)
# Out:
# False

# %%
bool(" 0")
# Out:
# True

# %%
bool("")
# Out:
# False

# %%
bool([])
# Out:
# False

# %%
bool({})
# Out:
# False

# %%
bool(0)
# Out:
# False

# %%
0 and None and 1
# Out:
# 0

# %%
False and False and True
# Out:
# False

# %%
True or True or True
# Out:
# True

# %%
False or False or False
# Out:
# False

# %%
0 or None or ""
# Out:
# ''

# %%
0 or 1 or 2 or ""
# Out:
# 1

# %%
not 1 # not her zaman için ya false verir yada true
# Out:
# False

# %%
print(2 and 3) # 2 ve 3 truty hepai truty ise son trutyi alı truty tanım
# Out:
# 3

# %%
print(1 and 0) # 1 truty 0 folsy  and ilk folsyi yakalar
# Out:
# 0

# %%
print(2 or "hello world")
print({})
# Out:
# 2
# {}

# %%
"clarus"[5] # indeks no
# Out:
# 's'

# %%
'okul'[2:4] # 2 den 4 e git 4 alma iki nokta slayş demek birden fazla eleman alıyor
# Out:
# 'ul'

# %%
fruit = "orange"
print(world )

# %%
print("sıcak ", " aynı zamanda bulutlu", sep= '+' ) # sep='' tırnak içine ne koyarsan satırları o işaretle ayırır
# Out:
# sıcak + aynı zamanda bulutlu

# %%
print("sıcak", end= '') # end='' ayrı printleri yan yana yazdırır
print(" + ", end= '')
print("aynı zamanda bulutlu")
# Out:
# sıcak + aynı zamanda bulutlu

# %%
print("sıcak", end="\n"  # end="\n" altalta yazdırır satırları
       "aynı zamanda bulutlu")
# Out:
# sıcak
# aynı zamanda bulutlu

# %%
x = 5
print("value of x     : ", x)
x += 2
print("2 more of x     : ", x, "\n")
y = 10
print("value of y     : ", y)
y -= 2
print("2 minus y    :", y, "\n")
# Out:
# value of x     :  5
# 2 more of x     :  7
#
# value of y     :  10
# 2 minus y    : 8

# %%
print([] and "Hello world!") # boş liste folsy dolu str truty and falseyi yakalar
# Out:
# []
